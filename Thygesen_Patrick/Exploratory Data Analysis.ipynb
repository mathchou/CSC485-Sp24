# %% [markdown]
# # Salary Dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('CSC485/CSC485-Sp24/Thygesen_P/salary_data_cleaned.csv')
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.isnull().sum()
# Out:
# Job Title            0
# Salary Estimate      0
# Job Description      0
# Rating               0
# Company Name         0
# Location             0
# Headquarters         0
# Size                 0
# Founded              0
# Type of ownership    0
# Industry             0
# Sector               0
# Revenue              0
# Competitors          0
# hourly               0
# employer_provided    0
# min_salary           0
# max_salary           0
# avg_salary           0
# company_txt          0
# job_state            0
# same_state           0
# age                  0
# python_yn            0
# R_yn                 0
# spark                0
# aws                  0
# excel                0
# dtype: int64

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.068733
# std      0.801210   497.183763    0.177034           0.149721   31.869282
# min     -1.000000    -1.000000    0.000000           0.000000   10.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age   python_yn        R_yn  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   127.183288  100.626011    0.557951   46.591644    0.528302    0.002695
# ...

# %%
average_salary_by_ownership = df.groupby('Type of ownership')['avg_salary'].mean().reset_index()
print(average_salary_by_ownership)
# Out:
#                  Type of ownership  avg_salary
# 0                               -1  117.500000
# 1             College / University  107.615385
# 2                Company - Private  101.776829
# 3                 Company - Public  110.893782
# 4                       Government   84.300000
# 5                         Hospital   54.000000
# 6           Nonprofit Organization   68.281818
# 7               Other Organization   77.500000
# 8         School / School District   77.750000
# 9   Subsidiary or Business Segment  110.573529
# 10                         Unknown   39.500000

# %%
plt.figure(figsize=(7,))
plt.bar(average_salary_by_ownership['Type of ownership'], average_salary_by_ownership['avg_salary'], color = 'pink')
plt.xlabel('Type of Ownership')
plt.ylabel('Average Salary')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
average_salary_by_sector = df.groupby('Sector')['avg_salary'].mean().reset_index()
print(average_salary_by_sector)
# Out:
#                                 Sector  avg_salary
# 0                                   -1  114.650000
# 1                   Accounting & Legal  113.500000
# 2                  Aerospace & Defense   99.060000
# 3               Agriculture & Forestry   80.500000
# 4     Arts, Entertainment & Recreation   48.500000
# 5            Biotech & Pharmaceuticals  111.767857
# 6                    Business Services   97.701031
# 7   Construction, Repair & Maintenance   26.500000
# 8                    Consumer Services   99.875000
# 9                            Education  100.739130
# 10                             Finance   97.369048
# 11                          Government   78.545455
# 12                         Health Care   67.622449
# 13              Information Technology  113.191667
# 14                           Insurance  105.942029
# 15                       Manufacturing   84.044118
# 16                               Media  116.666667
# ...

# %%
plt.figure(figsize=(7,4))
plt.bar(average_salary_by_sector['Sector'], average_salary_by_sector['avg_salary'], color = 'pink')
plt.xlabel('Sector')
plt.ylabel('Average Salary')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Some questions for this dataset could be:
# Which state has the highest salaries in a certain industry (i.e. Data Science)?
# Which sector has the highest average rating?
# Which type of company has a higher average rating?
# Which industry's have the oldest workers?

# %% [markdown]
# # Shopping Trends Dataset

# %%
df2 = pd.read_csv('CSC485/CSC485-Sp24/Thygesen_P/shopping_trends_updated.csv')
df2.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   55   Male         Blouse  Clothing                     53
# 1            2   19   Male        Sweater  Clothing                     64
# 2            3   50   Male          Jeans  Clothing                     73
# 3            4   21   Male        Sandals  Footwear                     90
# 4            5   45   Male         Blouse  Clothing                     49
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            3.1                 Yes
# 1          Maine    L     Maroon  Winter            3.1                 Yes
# 2  Massachusetts    S     Maroon  Spring            3.1                 Yes
# 3   Rhode Island    M     Maroon  Spring            3.5                 Yes
# 4         Oregon    M  Turquoise  Spring            2.7                 Yes
#
# ...

# %%
df2.isnull().sum()
# Out:
# Customer ID               0
# Age                       0
# Gender                    0
# Item Purchased            0
# Category                  0
# Purchase Amount (USD)     0
# Location                  0
# Size                      0
# Color                     0
# Season                    0
# Review Rating             0
# Subscription Status       0
# Shipping Type             0
# Discount Applied          0
# Promo Code Used           0
# Previous Purchases        0
# Payment Method            0
# Frequency of Purchases    0
# dtype: int64

# %%
df2.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3900.000000            3900.000000    3900.000000
# mean   1950.500000    44.068462              59.764359       3.749949
# std    1125.977353    15.207589              23.685392       0.716223
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.700000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
total_sales_by_items = df2.groupby('Item Purchased')['Purchase Amount (USD)'].sum().reset_index()
print(total_sales_by_items)
# Out:
#    Item Purchased  Purchase Amount (USD)
# 0        Backpack                   8636
# 1            Belt                   9635
# 2          Blouse                  10410
# 3           Boots                   9018
# 4            Coat                   9275
# 5           Dress                  10320
# 6          Gloves                   8477
# 7         Handbag                   8857
# 8             Hat                   9375
# 9          Hoodie                   8767
# 10         Jacket                   9249
# 11          Jeans                   7548
# 12        Jewelry                  10010
# 13          Pants                  10090
# 14        Sandals                   9200
# 15          Scarf                   9561
# 16          Shirt                  10332
# 17          Shoes                   9240
# 18         Shorts                   9433
# 19          Skirt                   9402
# 20       Sneakers                   8635
# 21          Socks                   9252
# ...

# %%
plt.figure(figsize=(7,4))
plt.bar(total_sales_by_items['Item Purchased'], total_sales_by_items['Purchase Amount (USD)'], color = 'pink')
plt.xlabel('Item')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
total_sales_by_season = df2.groupby('Season')['Purchase Amount (USD)'].sum().reset_index()
print(total_sales_by_season)
# Out:
#    Season  Purchase Amount (USD)
# 0    Fall                  60018
# 1  Spring                  58679
# 2  Summer                  55777
# 3  Winter                  58607

# %%
plt.figure(figsize=(7,4))
plt.bar(total_sales_by_season['Season'], total_sales_by_season['Purchase Amount (USD)'], color = 'blue')
plt.xlabel('Season')
plt.ylabel('Total Sales')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Questions to answer from this data Set:
# Which item of clothing sells the most in certain seasons?
# Which state has the highest sales?
# How does subscription status correlate with review ratings?

# %% [markdown]
# # Housing Data

# %%
df3 = pd.read_csv('CSC485/CSC485-Sp24/Thygesen_P/NY-House-Dataset.csv')
df3.head()
# Out:
#                                          BROKERTITLE                TYPE  \
# 0        Brokered by Douglas Elliman  -111 Fifth Ave      Condo for sale
# 1                                Brokered by Serhant      Condo for sale
# 2                             Brokered by Sowae Corp      House for sale
# 3                                Brokered by COMPASS      Condo for sale
# 4  Brokered by Sotheby's International Realty - E...  Townhouse for sale
#
#        PRICE  BEDS       BATH  PROPERTYSQFT  \
# 0     315000     2   2.000000        1400.0
# 1  195000000     7  10.000000       17545.0
# 2     260000     4   2.000000        2015.0
# 3      69000     3   1.000000         445.0
# 4   55000000     7   2.373861       14175.0
#
#                                              ADDRESS                    STATE  \
# 0                               2 E 55th St Unit 803       New York, NY 10022
# 1  Central Park Tower Penthouse-217 W 57th New Yo...       New York, NY 10019
# ...

# %%
df3.isnull().sum()
# Out:
# BROKERTITLE                    0
# TYPE                           0
# PRICE                          0
# BEDS                           0
# BATH                           0
# PROPERTYSQFT                   0
# ADDRESS                        0
# STATE                          0
# MAIN_ADDRESS                   0
# ADMINISTRATIVE_AREA_LEVEL_2    0
# LOCALITY                       0
# SUBLOCALITY                    0
# STREET_NAME                    0
# LONG_NAME                      0
# FORMATTED_ADDRESS              0
# LATITUDE                       0
# LONGITUDE                      0
# dtype: int64

# %%
df3.describe()
# Out:
#               PRICE         BEDS         BATH  PROPERTYSQFT     LATITUDE  \
# count  4.801000e+03  4801.000000  4801.000000   4801.000000  4801.000000
# mean   2.356940e+06     3.356801     2.373861   2184.207862    40.714227
# std    3.135525e+07     2.602315     1.946962   2377.140894     0.087676
# min    2.494000e+03     1.000000     0.000000    230.000000    40.499546
# 25%    4.990000e+05     2.000000     1.000000   1200.000000    40.639375
# 50%    8.250000e+05     3.000000     2.000000   2184.207862    40.726749
# 75%    1.495000e+06     4.000000     3.000000   2184.207862    40.771923
# max    2.147484e+09    50.000000    50.000000  65535.000000    40.912729
#
#          LONGITUDE
# count  4801.000000
# mean    -73.941601
# std       0.101082
# min     -74.253033
# 25%     -73.987143
# 50%     -73.949189
# 75%     -73.870638
# max     -73.702450

# %%
average_price_by_sublocality = df3.groupby('SUBLOCALITY')['PRICE'].mean().reset_index()
print(average_price_by_sublocality)
# Out:
#          SUBLOCALITY         PRICE
# 0       Bronx County  1.020866e+06
# 1           Brooklyn  8.646435e+05
# 2   Brooklyn Heights  6.250000e+05
# 3       Coney Island  5.113333e+05
# 4              Dumbo  5.799000e+06
# 5         East Bronx  2.650000e+05
# 6           Flushing  4.760000e+05
# 7      Fort Hamilton  5.990000e+05
# 8    Jackson Heights  9.850000e+05
# 9       Kings County  1.795465e+06
# 10         Manhattan  3.609905e+06
# 11          New York  2.534033e+06
# 12   New York County  1.019120e+07
# 13            Queens  4.437331e+05
# 14     Queens County  1.135774e+06
# 15         Rego Park  2.150000e+05
# 16   Richmond County  5.427598e+06
# 17         Riverdale  3.470000e+05
# 18     Snyder Avenue  6.500000e+05
# 19     Staten Island  4.475819e+05
# 20         The Bronx  3.366162e+05

# %%
plt.figure(figsize=(7,4))
plt.bar(average_price_by_sublocality['SUBLOCALITY'], average_price_by_sublocality['PRICE'], color = 'pink')
plt.xlabel('SUBLOCALITY')
plt.ylabel('PRICE')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %%
average_price_by_type = df3.groupby('TYPE')['PRICE'].mean().reset_index()
print(average_price_by_type)
# Out:
#                           TYPE         PRICE
# 0               Co-op for sale  1.100418e+06
# 1                  Coming Soon  1.172000e+06
# 2               Condo for sale  2.630710e+06
# 3              Condop for sale  9.986000e+05
# 4                   Contingent  8.825717e+05
# 5                     For sale  1.954536e+06
# 6                  Foreclosure  1.343010e+06
# 7               House for sale  3.684216e+06
# 8                Land for sale  1.073021e+06
# 9        Mobile house for sale  1.288000e+06
# 10  Multi-family home for sale  1.680428e+06
# 11                     Pending  1.340867e+06
# 12          Townhouse for sale  6.365925e+06

# %%
plt.figure(figsize=(7,4))
plt.bar(average_price_by_type['TYPE'], average_price_by_type['PRICE'], color = 'green')
plt.xlabel('TYPE')
plt.ylabel('PRICE')
plt.xticks(rotation=90)
plt.tight_layout()
plt.show()

# %% [markdown]
# Some possible questions to further explore with this dataset would be:
# How much an additional bed and bath cost in a house - correlation?
# How do the size of property's differ by each locality?
