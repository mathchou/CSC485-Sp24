# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
fields_of_study = ['Agriculture and natural resources Includes: agricultural, animal, plant, veterinary science, and related fields; and Natural resources and conservation.' , 'Architecture and related services' , 'Area; ethnic; cultural; gender; and group studies' , 'Biological and biomedical sciences' , 'Business Includes Business, management, marketing, and related support services; and Culinary, entertainment, and personal services.' , 'Communication; journalism; and related programs' , 'Communications technologies' , 'Computer and information sciences and support services' , 'Education' , 'Engineering' , 'Engineering technologies Includes Engineering technologies and engineering-related fields; Construction trades; and Mechanic and repair technologies/technicians.' , 'English language and literature/letters' , 'Family and consumer sciences/human sciences' , 'Foreign languages; literatures; and linguistics' , 'Health professions and related programs' , 'Homeland security; law enforcement; and firefighting' , 'Legal professions and studies' , '"Liberal arts and sciences; general studies; and' , '   humanities"' , 'Library science' , 'Mathematics and statistics' , 'Military technologies and applied sciences' , 'Multi/interdisciplinary studies' , 'Parks; recreation; leisure; fitness; and kinesiology' , 'Philosophy and religious studies' , 'Physical sciences and science technologies' , 'Precision production' , 'Psychology' , 'Public administration and social services' , 'Social sciences and history' , '  Social sciences' , '  History' , 'Theology and religious vocations' , 'Transportation and materials moving' , 'Visual and performing arts' , 'Other and not classified']

# %%
job_areas = ['Accommodation and Food Services' , ' Arts, Entertainment, and Recreation' , ' Construction' , ' Durable Goods Manufacturing' , ' Education and Health Services' , ' Government' , ' Health Care and Social Assistance' , ' Leisure and Hospitality' , ' Manufacturing' , ' Nondurable Goods Manufacturing' , ' Professional and Business Services' , ' Retail Trade' , ' State and Local' , ' Total Nonfarm' , ' Total Private' , ' Trade, Transportation, and Utilities']

# %%
df = pd.DataFrame(abs(np.random.randn(len(fields_of_study), len(job_areas))), index= fields_of_study, columns=job_areas)
df.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_338be_row0_col0, #T_338be_row2_col11, #T_338be_row5_col0, #T_338be_row8_col5, #T_338be_row27_col11, #T_338be_row30_col8 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_338be_row0_col1, #T_338be_row8_col2, #T_338be_row8_col15, #T_338be_row9_col2, #T_338be_row11_col11, #T_338be_row12_col11, #T_338be_row15_col0, #T_338be_row18_col9, #T_338be_row19_col9, #T_338be_row21_col8, #T_338be_row24_col4, #T_338be_row26_col8, #T_338be_row33_col6 {
#   background-color: #e1edf8;
#   color: #000000;
# }
# #T_338be_row0_col2, #T_338be_row3_col2, #T_338be_row3_col6, #T_338be_row9_col3, #T_338be_row11_col15, #T_338be_row28_col4 {
#   background-color: #b7d4ea;
#   color: #000000;
# }
# #T_338be_row0_col3, #T_338be_row34_col7 {
#   background-color: #d3e3f3;
#   color: #000000;
# }
# #T_338be_row0_col4 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_338be_row0_col5, #T_338be_row35_col11 {
#   background-color: #4594c7;
#   color: #f1f1f1;
# }
# ...

# %%
#import nltk
#nltk.download('wordnet')
from nltk.corpus import wordnet
syn1 = wordnet.synsets('hello')[0]
syn2 = wordnet.synsets('selling')[0]
 
print ("hello name :  ", syn1.name())
print ("selling name :  ", syn2.name())


syn1.wup_similarity(syn2)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mchou\AppData\Roaming\nltk_data...
# hello name :   hello.n.01
# selling name :   selling.n.01
# 0.26666666666666666

# %%
syn1 = wordnet.synsets('Arts')[0]
syn2 = wordnet.synsets('Communication')[0]

syn1.wup_similarity(syn2)
# Out:
# 0.42857142857142855
